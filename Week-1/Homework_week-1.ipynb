# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Q1. Read the data for January. How many columns are there?

# %%
# read dataframe and take a look
df_jan = pd.read_parquet('yellow_tripdata_2022-01.parquet')

# %%
df_jan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463931 entries, 0 to 2463930
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# ...

# %%
# print the rows and columns
print(df_jan.shape) 
df_jan.head()
# Out:
# (2463931, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# 1           2.10         1.0                  N           236            42
# 2           0.97         1.0                  N           166           166
# 3           1.09         1.0                  N           114            68
# 4           4.30         1.0                  N            68           163
#
# ...

# %% [markdown]
# ## Q1. Answer
#
# 19 columns

# %% [markdown]
# # Q2. Computing duration
#
# Now let's compute the duration variable. It should contain the duration of a ride in minutes.
#
# What's the standard deviation of the trips duration in January?

# %%
def create_target(df: pd.DataFrame) -> pd.DataFrame:
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    
    df['duration'] = df['duration'].apply(lambda duration: duration.total_seconds() / 60)
    
    return df

# %%
# Calculating the duration
create_target(df_jan)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
# Std
round(df_jan.duration.std(),2)
# Out:
# 46.45

# %% [markdown]
# ## Q2. Answer
#
# Standard deviation is 46.45

# %% [markdown]
# # Q3. Dropping outliers
#
# Next, we need to check the distribution of the duration variable. There are some outliers. Let's remove them and keep only the records where the duration was between 1 and 60 minutes (inclusive).
#
# What fraction of the records left after you dropped the outliers?

# %%
df_jan.duration.describe()
# Out:
# count    2.463931e+06
# mean     1.421220e+01
# std      4.644531e+01
# min     -3.442400e+03
# 25%      6.316667e+00
# 50%      1.018333e+01
# 75%      1.616667e+01
# max      8.513183e+03
# Name: duration, dtype: float64

# %%
def filter_df(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    return df.reset_index(drop=True)

# %%
# filtering the outliers between 1 and 60
df_jan_filtred = filter_df(df_jan)

# %%
# Get fraction of records left
df_jan_filtred.shape[0] / df_jan.shape[0] * 100
# Out:
# 98.27547930522405

# %% [markdown]
# ## Q3. Anwser
#
# The fraction is 98.27 (round - 98)

# %% [markdown]
# # Q4. One-hot encoding
#
# Let's apply one-hot encoding to the pickup and dropoff location IDs. We'll use only these two features for our model.
#
# * Turn the dataframe into a list of dictionaries
# * Fit a dictionary vectorizer
# * Get a feature matrix from it
# * What's the dimensionality of this matrix (number of columns)?

# %%
cat_columns = ['PULocationID', 'DOLocationID']
df_jan_filtred[cat_columns] = df_jan_filtred[cat_columns].astype(str)
train_dicts = df_jan_filtred[cat_columns].to_dict(orient='records')



dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train.shape
# Out:
# (2421440, 515)

# %% [markdown]
# ## Q4. Anwser
#
# 515 columns

# %% [markdown]
# # Q5. Training a model
# Now let's use the feature matrix from the previous step to train a model.
#
# * Train a plain linear regression model with default parameters
# * Calculate the RMSE of the model on the training data
# * What's the RMSE on train?

# %%
y_train = df_jan_filtred.duration.values

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
round(mean_squared_error(y_train, y_pred, squared=False),2)
# Out:
# 6.99

# %% [markdown]
# ## Q5. Anwser
#
# RMSE 6.99

# %% [markdown]
# # Q6. Evaluating the model
#
# Now let's apply this model to the validation dataset (February 2022).
#
# What's the RMSE on validation?

# %%
df_feb = pd.read_parquet('yellow_tripdata_2022-02.parquet')
print(df_feb.shape)
df_feb.head()
# Out:
# (2979431, 19)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-02-01 00:06:58   2022-02-01 00:19:24              1.0
# 1         1  2022-02-01 00:38:22   2022-02-01 00:55:55              1.0
# 2         1  2022-02-01 00:03:20   2022-02-01 00:26:59              1.0
# 3         2  2022-02-01 00:08:00   2022-02-01 00:28:05              1.0
# 4         2  2022-02-01 00:06:48   2022-02-01 00:33:07              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           5.40         1.0                  N           138           252
# 1           6.40         1.0                  N           138            41
# 2          12.50         1.0                  N           138           200
# 3           9.88         1.0                  N           239           200
# 4          12.16         1.0                  N           138           125
#
# ...

# %%
create_target(df_feb)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-02-01 00:06:58   2022-02-01 00:19:24              1.0
# 1               1  2022-02-01 00:38:22   2022-02-01 00:55:55              1.0
# 2               1  2022-02-01 00:03:20   2022-02-01 00:26:59              1.0
# 3               2  2022-02-01 00:08:00   2022-02-01 00:28:05              1.0
# 4               2  2022-02-01 00:06:48   2022-02-01 00:33:07              1.0
# ...           ...                  ...                   ...              ...
# 2979426         2  2022-02-28 23:50:00   2022-03-01 00:06:00              NaN
# 2979427         2  2022-02-28 23:06:57   2022-02-28 23:19:12              NaN
# 2979428         2  2022-02-28 23:48:13   2022-03-01 00:03:33              NaN
# 2979429         2  2022-02-28 23:56:41   2022-03-01 00:04:57              NaN
# 2979430         2  2022-02-28 23:04:00   2022-02-28 23:10:00              NaN
#
# ...

# %%
df_feb_fitered = filter_df(df_feb)

# %%
df_feb_fitered[cat_columns] = df_feb_fitered[cat_columns].astype(str)

# %%
val_dicts = df_feb_fitered[cat_columns].to_dict(orient='records')

# %%
X_val = dv.transform(val_dicts)
print(X_val.shape)
# Out:
# (2918187, 515)

# %%
y_val = df_feb_fitered['duration'].values

# %%
y_pred_val = lr.predict(X_val)

# %%
round(mean_squared_error(y_val, y_pred_val, squared=False),2)
# Out:
# 7.79

# %% [markdown]
# ## Q6. Anwser
# RMSE 7.79
